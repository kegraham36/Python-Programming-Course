# %%
print("Hello, my name is Kailyn and I am learning Python.")

num1 = 20
num2 = 22
answer = num1 + num2

print("The answer is", answer)
# Out:
# Hello, my name is Kailyn and I am learning Python.
# The answer is 42
